# %%
from tensorflow import keras
import pickle
from google.colab import drive
drive.mount('/content/gdrive')
# # load the model from disk
# loaded_model = pickle.load(open('/content/gdrive/MyDrive/thesis_work/arcfaceresnet100-8.onnx', 'rb'))
# print(type(loaded_model))
# loaded_model.fit("/content/gdrive/MyDrive/1517763395598.jpg", 'siva')

# import onnx2keras
# from onnx2keras import onnx_to_keras
# import keras
# import onnx

import tensorflow as tf
# import tensorflow.compat.v1 as tf
# tf.disable_v2_behavior()
# from tensorflow.python.platform import gfile
# with tf.Session() as sess:
#     model_filename ='/content/gdrive/MyDrive/thesis_work/MobileFaceNet_9925_9680.pb'
#     with gfile.FastGFile(model_filename, 'rb') as f:
#         graph_def = tf.GraphDef()
#         graph_def.ParseFromString(f.read())
#         g_in = tf.import_graph_def(graph_def)
# LOGDIR='/content/gdrive/MyDrive/thesis_work/'
# train_writer = tf.summary.FileWriter(LOGDIR)
# train_writer.add_graph(sess.graph)

# import tensorflow as tf
# from tensorflow.python.platform import gfile
# GRAPH_PB_PATH = './frozen_model.pb'
# with tf.Session() as sess:
#    print("load graph")
#    with gfile.FastGFile(GRAPH_PB_PATH,'rb') as f:
#        graph_def = tf.GraphDef()
#    graph_def.ParseFromString(f.read())
#    sess.graph.as_default()
#    tf.import_graph_def(graph_def, name='')
#    graph_nodes=[n for n in graph_def.node]
#    names = []
#    for t in graph_nodes:
#       names.append(t.name)
#    print(names)

# model = tf.keras.models.load_model('/content/gdrive/MyDrive/thesis_work/MobileFaceNet_9925_9680.pb')

import os
import tensorflow as tf
from tensorflow.keras.preprocessing import image

New_Model = tf.keras.models.load_model('/content/gdrive/MyDrive/thesis_work/MobileFaceNet_9925_9680.pb') # Loading the Tensorflow Saved Model (PB)
print(New_Model.summary())
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-0b76ecac9aad> in <module>()
#      49 from tensorflow.keras.preprocessing import image
#      50
# ---> 51 New_Model = tf.keras.models.load_model('/content/gdrive/MyDrive/thesis_work/MobileFaceNet_9925_9680.pb') # Loading the Tensorflow Saved Model (PB)
#      52 print(New_Model.summary())
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ...

# %%
k_model.summary()
k_model._layers.pop(-1)
k_model._layers.pop(-1)
k_model.summary()

newInput = Input(batch_shape=(1,1,200,200))
newOutputs = k_model(newInput)
newModel = Model(newInput,newOutputs)
newModel.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8d7459012090> in <module>()
# ----> 1 k_model.summary()
#       2 k_model._layers.pop(-1)
#       3 k_model._layers.pop(-1)
#       4 k_model.summary()
#       5
#
# NameError: name 'k_model' is not defined

# %%
# !pip install --upgrade onnx2keras
# Out:
# ...
#      |████████████████████████████████| 12.8 MB 7.3 MB/s
# ...
#      |████████████████████████████████| 462 kB 59.9 MB/s
# ...
#   Created wheel for onnx2keras: filename=onnx2keras-0.0.24-py3-none-any.whl size=24593 sha256=271ca833daa1f3c10b240cb174b504f9ec193ffd34f847bbf2897a88f80e1d8d
#   Stored in directory: /root/.cache/pip/wheels/21/29/29/227fc9f8fed234b12169ae41f979cfadf1dcdbe1b370a5bbb5
# Successfully built onnx2keras
# ...

# %%
# !ls /content/gdrive/MyDrive/thesis_work/
# Out:
# ls: cannot access '/content/gdrive/MyDerive/thesis_work/face_recognition_mv.pkl': No such file or directory

# %%
# !pip install tflite
# Out:
# ...
#      |████████████████████████████████| 87 kB 3.4 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !tflite_convert --output_file MobileFaceNet.tflite   --input_arrays "input" --input_shapes "1,112,112,3" --output_arrays embeddings --output_format TFLITE --saved_model_dir '/content/gdrive/MyDrive/thesis_work/'
# Out:
# Mounted at /content/gdrive
# [libprotobuf ERROR google/protobuf/wire_format_lite.cc:577] String field 'tensorflow.MetaGraphDef.MetaInfoDef.meta_graph_version' contains invalid UTF-8 data when parsing a protocol buffer. Use the 'bytes' type if you intend to send raw bytes.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py", line 102, in parse_saved_model
#     saved_model.ParseFromString(file_content)
# google.protobuf.message.DecodeError: Error parsing message
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/tflite_convert", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/tflite_convert.py", line 693, in main
#     app.run(main=run_main, argv=sys.argv[:1])
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 312, in run
# ...

# %%
#import keras
from google.colab import drive
drive.mount('/content/gdrive')
import os
import tensorflow as tf
from tensorflow.keras.preprocessing import image

pb_model_dir = "/content/gdrive/MyDrive/thesis_work/mobilefacenet_model/"
h5_model = "/content/gdrive/MyDrive/thesis_work/mobilefacenet.h5"

# Loading the Tensorflow Saved Model (PB)
model = tf.keras.models.load_model(pb_model_dir)
print(model.summary())

# Saving the Model in H5 Format
tf.keras.models.save_model(model, h5_model)

# Loading the H5 Saved Model
loaded_model_from_h5 = tf.keras.models.load_model(h5_model)
print(loaded_model_from_h5.summary())
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-c3bf8d06a69f> in <module>()
#      10
#      11 # Loading the Tensorflow Saved Model (PB)
# ---> 12 model = tf.keras.models.load_model(pb_model_dir)
#      13 print(model.summary())
#      14
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
# ...

# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

with tf.Session(graph=tf.Graph()) as sess:
    tf.saved_model.loader.load(
        sess, [tf.saved_model.tag_constants.SERVING], "/content/gdrive/MyDrive/thesis_work/mobilefacenet_model/")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From <ipython-input-8-df0028935136>:7: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# ---------------------------------------------------------------------------
# DecodeError                               Traceback (most recent call last)
# ...

# %%
model = tf.keras.models.load_model('/content/gdrive/MyDrive/thesis_work/mobilefacenet_model/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-c50dcb4bd223> in <module>()
# ----> 1 model = tf.keras.models.load_model('/content/gdrive/MyDrive/thesis_work/mobilefacenet_model/')
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     103       return saved_model
#     104     except message.DecodeError as e:
# --> 105       raise IOError(f"Cannot parse file {path_to_pb}: {str(e)}.")
# ...

# %%
# !ls -l /content/gdrive/MyDrive/thesis_work/mobilefacenet_model/saved_model.pb
# Out:
# -rw------- 1 root root 5956310 May  1 15:51 /content/gdrive/MyDrive/thesis_work/mobilefacenet_model/saved_model.pb

# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf
import sys
from tensorflow.python.platform import gfile

from tensorflow.core.protobuf import saved_model_pb2
from tensorflow.python.util import compat
with tf.Session() as persisted_sess:
  print("load graph")
  with gfile.FastGFile("/content/gdrive/MyDrive/thesis_work/mobilefacenet_model/saved_model.pb",'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    persisted_sess.graph.as_default()
    tf.import_graph_def(graph_def, name='')
    writer = tf.summary.FileWriter("./tf_summary", graph=persisted_sess.graph)
    # Print all operation names
    for op in persisted_sess.graph.get_operations():
      print(op)
    # next: do the following in bash:
    # tensorboard --logdir ./tf_summary/
# Out:
# Streaming output truncated to the last 5000 lines.
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#         dim {
#           size: 128
#         }
#       }
# ...
